# %% [markdown]
# Task 1: Enhance image quality to deal with varying lighting conditions.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image_path = '/content/1069.jpg'
image = cv2.imread(image_path)

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_image = clahe.apply(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)# Convert the images back to RGB for display in matplotlib
clahe_image_rgb = cv2.cvtColor(clahe_image, cv2.COLOR_GRAY2RGB)


r, g, b = cv2.split(image_rgb)

clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))

r_clahe = clahe.apply(r)
g_clahe = clahe.apply(g)
b_clahe = clahe.apply(b)

# Merge the CLAHE
clahe_image_rgb = cv2.merge([r_clahe, g_clahe, b_clahe])

plt.figure(figsize=(16, 9))
plt.subplot(121)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(122)
plt.imshow(clahe_image_rgb)
plt.title('Contrast Limited AHE (CLAHE)')
plt.axis('off')
# Out:
# (-0.5, 511.5, 255.5, -0.5)

# %% [markdown]
# Task 2:Detect edges of vehicles and road markings to assess traffic patterns.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img=cv.imread('/content/174.jpg',cv2.IMREAD_GRAYSCALE)

sobel_x=cv.Sobel(img,-1,1,0,3)
sobel_y=cv.Sobel(img,-1,0,1,3)
#laplacian= cv.Laplacian(img,-1,3)# (src_img,ddepth,kernel_size)
# combined = cv2.addWeighted(sobel_x, 0.5, sobel_y, 0.5, 0)# 0.5 is the weight applied to sobel_x and sobel_y
# combined = cv2.convertScaleAbs(combined)#cv2.convertScaleAbs() converts the pixel values from a floating-point
#combined =cv.bitwise_xor(sobel_x,sobel_y)
lower_threshold=100
upper_threshold=200
canny=cv.Canny(img,lower_threshold,upper_threshold)

plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.imshow(img,cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Canny Image')
plt.imshow(canny, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Task 3: Apply filters to reduce noise and improve the clarity of moving objects

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/content/1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
assert img is not None, "file could not be read, check with os.path.exists()"

bilateral_blur=cv2.bilateralFilter(img,9,75,75)

plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.imshow(img,cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(bilateral_blur,cmap='gray')
plt.title('Bilateral Blur')
plt.axis('off')
plt.show()
